# %%
from bs4 import BeautifulSoup
import pandas as pd
import glob
import os
from tqdm import tqdm

# %%
regular = []
advandce = []
for file in glob.glob(r'C:\Users\jacks\Documents\GitHub\NCAA Predictions\HTMLs\*.html'):
    if 'advandce' in file:
        advandce.append(file)
    else:
        regular.append(file)

# %%
regular
# Out:
# ['C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2014_gamelogs.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2015_gamelogs.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2016_gamelogs.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2017_gamelogs.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2018_gamelogs.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2019_gamelogs.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2020_gamelogs.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2021_gamelogs.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\air-force_2011_gamelogs.html',
# ...

# %%
advandce
# Out:
# ['C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\ loyola-marymount_2011_gamelogs_advandce.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\ loyola-marymount_2012_gamelogs_advandce.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\ loyola-marymount_2013_gamelogs_advandce.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\ loyola-marymount_2014_gamelogs_advandce.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\ loyola-marymount_2015_gamelogs_advandce.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\ loyola-marymount_2016_gamelogs_advandce.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\ loyola-marymount_2017_gamelogs_advandce.html',
#  'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\ loyola-marymount_2018_gamelogs_advandce.html',
# ...

# %%
years = ['2021', '2020', '2019', '2018', '2017', '2017', '2016', '2015', '2014', '2013', '2012', '2011']
types = ['gamelogs.html', 'gamelogs_advandce.html']

# %%
#Test get data
test1 = 'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2011_gamelogs.html'
test2 = 'C:\\Users\\jacks\\Documents\\GitHub\\NCAA Predictions\\HTMLs\\abilene-christian_2011_gamelogs_advandce.html'
